# %%
# %load_ext autoreload
# %autoreload 2

# %%
from youtube_api import YouTubeDataAPI

api_key = "AIzaSyCT1xN2Lc6Cni3jtyzVdPEQqr6mw001BlM"
yt = YouTubeDataAPI(api_key)

teambro_channel_id = "UCIYNYv9ddZBg42gvyp8L2Iw"

# %%
ret = yt.search(channel_id=teambro_channel_id, max_results=1000)

# %% [raw]
# for data in ret:
#     print(data)

# %%
comments = yt.get_video_comments(video_id=sample["video_id"])

# %% [raw]
# for cm in comments:
#     print(cm)

# %%
from analyzer import YoutubeCommentAnalyzer

# %%
yt = YoutubeCommentAnalyzer(key=api_key)

# %%
ret = yt.get_comments_from_channel(teambro_channel_id)
# Out:
# 0th video done
# 1th video done

# %%
ret[2]["comments"]
# Out:
# [{'video_id': 'bHwyZ1Y4Tvg',
#   'commenter_channel_url': 'http://www.youtube.com/channel/UCIYNYv9ddZBg42gvyp8L2Iw',
#   'commenter_channel_id': 'UCIYNYv9ddZBg42gvyp8L2Iw',
#   'commenter_channel_display_name': '팀브라더스',
#   'comment_id': 'UgwQ-mSd_G8f13XNwsl4AaABAg',
#   'comment_like_count': 11,
#   'comment_publish_date': datetime.datetime(2018, 12, 28, 12, 10, 31),
#   'text': '오늘은 저희가 제로페이를 이용해서! 소소한 송년회를 준비해봤습니다! \n여러분 모두 송년회 무리하지 마시고요! 많이 먹고 많이 노는 것도 좋지만!\n무엇보다 건강한 송년회 가지세요!!',
#   'commenter_rating': 'none',
#   'comment_parent_id': None,
#   'collection_date': datetime.datetime(2020, 4, 19, 18, 4, 24, 990776),
#   'reply_count': 0},
#  {'video_id': 'bHwyZ1Y4Tvg',
#   'commenter_channel_url': 'http://www.youtube.com/channel/UCWIuhTL-ohWrtD4uZ95T02Q',
#   'commenter_channel_id': 'UCWIuhTL-ohWrtD4uZ95T02Q',
#   'commenter_channel_display_name': '얼굴큰 오빠大脸欧巴',
#   'comment_id': 'UgxyU-dfcM88w3KeH9d4AaABAg',
#   'comment_like_count': 1,
# ...

# %%
print(ret[2]["link"])
# Out:
# https://www.youtube.com/watch?v=bHwyZ1Y4Tvg

# %%
ret[2]
# Out:
# {'video_id': 'bHwyZ1Y4Tvg',
#  'channel_title': '팀브라더스',
#  'channel_id': 'UCIYNYv9ddZBg42gvyp8L2Iw',
#  'video_publish_date': datetime.datetime(2018, 12, 28, 12, 0, 7),
#  'video_title': '대표님 없이 송년회 하는 방법 ㅋㅋㅋㅋㅋ (feat. 제로페이)',
#  'video_description': '대표님 미안해! 송년회 안 불러서 미안해! 여러분 안녕하세요?! 어느덧 2018년 한 해가 끝나가고 있네요 여러분들의 2018년 한 해 다들 어떠셨나요!...',
#  'video_category': None,
#  'video_thumbnail': 'https://i.ytimg.com/vi/bHwyZ1Y4Tvg/hqdefault.jpg',
#  'collection_date': datetime.datetime(2020, 4, 19, 18, 4, 7, 721361),
#  'link': 'https://www.youtube.com/watch?v=bHwyZ1Y4Tvg',
#  'comments': [{'video_id': 'bHwyZ1Y4Tvg',
#    'commenter_channel_url': 'http://www.youtube.com/channel/UCIYNYv9ddZBg42gvyp8L2Iw',
#    'commenter_channel_id': 'UCIYNYv9ddZBg42gvyp8L2Iw',
#    'commenter_channel_display_name': '팀브라더스',
#    'comment_id': 'UgwQ-mSd_G8f13XNwsl4AaABAg',
#    'comment_like_count': 11,
#    'comment_publish_date': datetime.datetime(2018, 12, 28, 12, 10, 31),
# ...
